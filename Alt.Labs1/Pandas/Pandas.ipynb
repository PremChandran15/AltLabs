# %% [markdown]
# # Pandas

# %%
import numpy as np
import pandas as pd

# %% [markdown]
# ## Data Frames

# %%
np.random.randint(0,100,25)
# Out:
# array([98, 62, 95, 35, 31, 88, 10, 77, 57, 34, 62, 91, 76, 56, 33, 54, 59,
#        82, 80, 63, 65, 45,  9, 41, 54])

# %%
np.random.seed(42)
df = pd.DataFrame(data=np.random.randint(0,100,25).reshape(5,5),index=np.arange(1,6),columns=['A','B','C','D','E'])

# %%
df
# Out:
#     A   B   C   D   E
# 1  51  92  14  71  60
# 2  20  82  86  74  74
# 3  87  99  23   2  21
# 4  52   1  87  29  37
# 5   1  63  59  20  32

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 5 entries, 1 to 5
# Data columns (total 5 columns):
# A    5 non-null int64
# B    5 non-null int64
# C    5 non-null int64
# D    5 non-null int64
# E    5 non-null int64
# dtypes: int64(5)
# memory usage: 240.0 bytes

# %%
df.describe()
# Out:
#                A          B          C          D         E
# count   5.000000   5.000000   5.000000   5.000000   5.00000
# mean   42.200000  67.400000  53.800000  39.200000  44.80000
# std    33.056013  39.513289  34.273897  31.932742  21.64948
# min     1.000000   1.000000  14.000000   2.000000  21.00000
# 25%    20.000000  63.000000  23.000000  20.000000  32.00000
# 50%    51.000000  82.000000  59.000000  29.000000  37.00000
# 75%    52.000000  92.000000  86.000000  71.000000  60.00000
# max    87.000000  99.000000  87.000000  74.000000  74.00000

# %%
df[['A','B']]
# Out:
#     A   B
# 1  51  92
# 2  20  82
# 3  87  99
# 4  52   1
# 5   1  63

# %%
df["addition of A+B"] = df['A'] + df['B']

# %%
df
# Out:
#     A   B   C   D   E  addition of A+B
# 1  51  92  14  71  60              143
# 2  20  82  86  74  74              102
# 3  87  99  23   2  21              186
# 4  52   1  87  29  37               53
# 5   1  63  59  20  32               64

# %%
df[df['A']>3]
# Out:
#     A   B   C   D   E  addition of A+B
# 1  51  92  14  71  60              143
# 2  20  82  86  74  74              102
# 3  87  99  23   2  21              186
# 4  52   1  87  29  37               53

# %%
df.iloc[2]
# Out:
# A                   87
# B                   99
# C                   23
# D                    2
# E                   21
# addition of A+B    186
# Name: 3, dtype: int64

# %% [markdown]
# ## GroupBy

# %%
data = {'Company':['GOOG','GOOG','MSFT','MSFT','FB','FB'],
       'Person':['Sam','Charlie','Amy','Vanessa','Carl','Sarah'],
       'Sales':[200,120,340,124,243,350]}

df2 = pd.DataFrame(data)
df2
# Out:
#   Company   Person  Sales
# 0    GOOG      Sam    200
# 1    GOOG  Charlie    120
# 2    MSFT      Amy    340
# 3    MSFT  Vanessa    124
# 4      FB     Carl    243
# 5      FB    Sarah    350

# %%
# Groupby is typically used for aggregation of data. eg: sum, mean, std, max, etc
df2.groupby('Company').mean()
# Out:
#          Sales
# Company
# FB       296.5
# GOOG     160.0
# MSFT     232.0

# %%
df2.groupby('Company').describe()
# Out:
#         Sales
#         count   mean         std    min     25%    50%     75%    max
# Company
# FB        2.0  296.5   75.660426  243.0  269.75  296.5  323.25  350.0
# GOOG      2.0  160.0   56.568542  120.0  140.00  160.0  180.00  200.0
# MSFT      2.0  232.0  152.735065  124.0  178.00  232.0  286.00  340.0

# %% [markdown]
# ## Pandas Missing Data

# %%
df2.isnull()
# Out:
#    Company  Person  Sales
# 0    False   False  False
# 1    False   False  False
# 2    False   False  False
# 3    False   False  False
# 4    False   False  False
# 5    False   False  False

# %%
data2 = {'Company':['GOOG','GOOG','MSFT','MSFT','FB','FB'],
       'Person':['Sam','Charlie','Amy','Vanessa','Carl','Sarah'],
       'Sales':[200,120,np.nan,124,243,350]}

df3 = pd.DataFrame(data2)
df3
# Out:
#   Company   Person  Sales
# 0    GOOG      Sam  200.0
# 1    GOOG  Charlie  120.0
# 2    MSFT      Amy    NaN
# 3    MSFT  Vanessa  124.0
# 4      FB     Carl  243.0
# 5      FB    Sarah  350.0

# %%
df3.isnull()
# Out:
#    Company  Person  Sales
# 0    False   False  False
# 1    False   False  False
# 2    False   False   True
# 3    False   False  False
# 4    False   False  False
# 5    False   False  False

# %%
df3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6 entries, 0 to 5
# Data columns (total 3 columns):
# Company    6 non-null object
# Person     6 non-null object
# Sales      5 non-null float64
# dtypes: float64(1), object(2)
# memory usage: 224.0+ bytes

# %%
df3.fillna('FILLED',inplace=True)

# %%
df3
# Out:
#   Company   Person   Sales
# 0    GOOG      Sam     200
# 1    GOOG  Charlie     120
# 2    MSFT      Amy  FILLED
# 3    MSFT  Vanessa     124
# 4      FB     Carl     243
# 5      FB    Sarah     350

# %% [markdown]
# ## Pandas Operations

# %%
df['A'].apply(lambda num: num-3)
# Out:
# 1    48
# 2    17
# 3    84
# 4    49
# 5    -2
# Name: A, dtype: int64

# %%
df
# Out:
#     A   B   C   D   E  addition of A+B
# 1  51  92  14  71  60              143
# 2  20  82  86  74  74              102
# 3  87  99  23   2  21              186
# 4  52   1  87  29  37               53
# 5   1  63  59  20  32               64

# %%
df['A'].unique()
# Out:
# array([51, 20, 87, 52,  1])

# %%
df['A'].nunique()
# Out:
# 5

# %%
df2['Company'].value_counts()
# Out:
# GOOG    2
# FB      2
# MSFT    2
# Name: Company, dtype: int64

# %% [markdown]
# ## Data Input and Output

# %% [markdown]
# ## Pandas Exercises

# %%
data_df = pd.read_csv('Salaries.csv')
data_df.head()
# Out:
#    Id       EmployeeName                                        JobTitle  \
# 0   1     NATHANIEL FORD  GENERAL MANAGER-METROPOLITAN TRANSIT AUTHORITY
# 1   2       GARY JIMENEZ                 CAPTAIN III (POLICE DEPARTMENT)
# 2   3     ALBERT PARDINI                 CAPTAIN III (POLICE DEPARTMENT)
# 3   4  CHRISTOPHER CHONG            WIRE ROPE CABLE MAINTENANCE MECHANIC
# 4   5    PATRICK GARDNER    DEPUTY CHIEF OF DEPARTMENT,(FIRE DEPARTMENT)
#
#      BasePay  OvertimePay   OtherPay  Benefits   TotalPay  TotalPayBenefits  \
# 0  167411.18         0.00  400184.25       NaN  567595.43         567595.43
# 1  155966.02    245131.88  137811.38       NaN  538909.28         538909.28
# 2  212739.13    106088.18   16452.60       NaN  335279.91         335279.91
# 3   77916.00     56120.71  198306.90       NaN  332343.61         332343.61
# 4  134401.60      9737.00  182234.59       NaN  326373.19         326373.19
#
#    Year  Notes         Agency  Status
# 0  2011    NaN  San Francisco     NaN
# 1  2011    NaN  San Francisco     NaN
# 2  2011    NaN  San Francisco     NaN
# 3  2011    NaN  San Francisco     NaN
# 4  2011    NaN  San Francisco     NaN

# %%
data_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 148654 entries, 0 to 148653
# Data columns (total 13 columns):
# Id                  148654 non-null int64
# EmployeeName        148654 non-null object
# JobTitle            148654 non-null object
# BasePay             148045 non-null float64
# OvertimePay         148650 non-null float64
# OtherPay            148650 non-null float64
# Benefits            112491 non-null float64
# TotalPay            148654 non-null float64
# TotalPayBenefits    148654 non-null float64
# Year                148654 non-null int64
# Notes               0 non-null float64
# Agency              148654 non-null object
# Status              0 non-null float64
# dtypes: float64(8), int64(2), object(3)
# memory usage: 14.7+ MB

# %%
data_df.describe()
# Out:
#                   Id        BasePay    OvertimePay       OtherPay  \
# count  148654.000000  148045.000000  148650.000000  148650.000000
# mean    74327.500000   66325.448841    5066.059886    3648.767297
# std     42912.857795   42764.635495   11454.380559    8056.601866
# min         1.000000    -166.010000      -0.010000   -7058.590000
# 25%     37164.250000   33588.200000       0.000000       0.000000
# 50%     74327.500000   65007.450000       0.000000     811.270000
# 75%    111490.750000   94691.050000    4658.175000    4236.065000
# max    148654.000000  319275.010000  245131.880000  400184.250000
#
#             Benefits       TotalPay  TotalPayBenefits           Year  Notes  \
# count  112491.000000  148654.000000     148654.000000  148654.000000    0.0
# mean    25007.893151   74768.321972      93692.554811    2012.522643    NaN
# std     15402.215858   50517.005274      62793.533483       1.117538    NaN
# min       -33.890000    -618.130000       -618.130000    2011.000000    NaN
# 25%     11535.395000   36168.995000      44065.650000    2012.000000    NaN
# 50%     28628.620000   71426.610000      92404.090000    2013.000000    NaN
# 75%     35566.855000  105839.135000     132876.450000    2014.000000    NaN
# max     96570.660000  567595.430000     567595.430000    2014.000000    NaN
#
#        Status
# count     0.0
# mean      NaN
# std       NaN
# min       NaN
# 25%       NaN
# 50%       NaN
# 75%       NaN
# max       NaN

# %%
data_df.isnull().head()
# Out:
#       Id  EmployeeName  JobTitle  BasePay  OvertimePay  OtherPay  Benefits  \
# 0  False         False     False    False        False     False      True
# 1  False         False     False    False        False     False      True
# 2  False         False     False    False        False     False      True
# 3  False         False     False    False        False     False      True
# 4  False         False     False    False        False     False      True
#
#    TotalPay  TotalPayBenefits   Year  Notes  Agency  Status
# 0     False             False  False   True   False    True
# 1     False             False  False   True   False    True
# 2     False             False  False   True   False    True
# 3     False             False  False   True   False    True
# 4     False             False  False   True   False    True

# %%
#average base pay
data_df['BasePay'].mean()
# Out:
# 66325.44884050643

# %%
#Highest amount of  overtime pay in the dataset
data_df['OvertimePay'].max()
# Out:
# 245131.88

# %%
#What is the job title of JOSEPH DRISCOLL
data_df[data_df["EmployeeName"]=="JOSEPH DRISCOLL"]['JobTitle']
# Out:
# 24    CAPTAIN, FIRE SUPPRESSION
# Name: JobTitle, dtype: object

# %%
#How much does JOSEPH DRISCOLL make (including benefits)?
data_df[data_df["EmployeeName"]=="JOSEPH DRISCOLL"]['TotalPayBenefits']
# Out:
# 24    270324.91
# Name: TotalPayBenefits, dtype: float64

# %%
#What is the name of highest paid person (including benefits)?
data_df[data_df["TotalPayBenefits"]==data_df["TotalPayBenefits"].max()]["EmployeeName"]
# Out:
# 0    NATHANIEL FORD
# Name: EmployeeName, dtype: object

# %%
#What is the name of lowest paid person (including benefits)?
data_df[data_df["TotalPayBenefits"]==data_df["TotalPayBenefits"].min()]
# Out:
#             Id EmployeeName                    JobTitle  BasePay  OvertimePay  \
# 148653  148654    Joe Lopez  Counselor, Log Cabin Ranch      0.0          0.0
#
#         OtherPay  Benefits  TotalPay  TotalPayBenefits  Year  Notes  \
# 148653   -618.13       0.0   -618.13           -618.13  2014    NaN
#
#                Agency  Status
# 148653  San Francisco     NaN

# %%
#What was the average (mean) BasePay of all employees per year? (2011-2014) ?
data_df.groupby('Year')['BasePay'].mean()
# Out:
# Year
# 2011    63595.956517
# 2012    65436.406857
# 2013    69630.030216
# 2014    66564.421924
# Name: BasePay, dtype: float64

# %%
#How many unique job titles are there?
data_df['JobTitle'].nunique()
# Out:
# 2159

# %%
#What are the top 5 most common jobs?
#METHOD 1 = using value_counts
data_df['JobTitle'].value_counts().head()
# Out:
# Transit Operator                7036
# Special Nurse                   4389
# Registered Nurse                3736
# Public Svc Aide-Public Works    2518
# Police Officer 3                2421
# Name: JobTitle, dtype: int64

# %%
#METHOD 2= using sort_values and then looping through it like typical SQL method 
data_df.sort_values(by='JobTitle')
# Out:
#             Id            EmployeeName  \
# 24456    24457              MARINE MAK
# 35637    35638           TSE SHIH LENG
# 26437    26438              LILA CHENG
# 24574    24575  JOCELYN VERGEL DE DIOS
# 26235    26236           ALICE BRONSON
# 24779    24780           CHRISTINE QIU
# 26443    26444             ZAIRE EARBY
# 27189    27190        BRIDGETT BUCKLEY
# 20765    20766          NAPOLEON VIRAY
# 28014    28015          OLENA VOLYNETS
# 25238    25239          JUDITH PALANCA
# 24766    24767            TSUI-HWA LEE
# 22972    22973        OLIVIA BOUDREAUX
# 27761    27762           JANICE ARAGON
# 24767    24768             OSCAR MIRON
# 24577    24578         GORGONIA MARTIN
# 27567    27568         BEVERLY JOHNSON
# 24578    24579            PRAVIN DESAI
# 24777    24778          KENNETH UCHIDA
# 24776    24777           KAMILLE MASON
# 24416    24417         PRISCILLA VUONG
# 24449    24450         JOAQUIN ANDALUZ
# 24758    24759               HELENA NG
# 26289    26290         WING YIN EST IP
# 26342    26343              SHELLY LIU
# 25387    25388                 JADE LI
# 24793    24794      CHRISTOPHER COFFEY
# 24788    24789               JAMES LIU
# 24636    24637                 DAW WIN
# 29433    29434           SUZANNE ZHENG
# ...        ...                     ...
# 139672  139673        Katrina R Daumas
# 90102    90103       Nathaniel C Intal
# 127941  127942         Rafael V Ibarra
# 66120    66121            David Kelley
# 56386    56387          Anitha Jackson
# 55802    55803   Christopher Gutierrez
# 95045    95046         Marlon F Oviedo
# 66095    66096          William Hester
# 141976  141977      Boniface N Emelife
# 126697  126698             Delbert Lee
# 130097  130098        Anitha F Jackson
# 109794  109795        William G Hester
# 103259  103260         Kimberly  Grice
# 99851    99852         Malika I Crosby
# 136430  136431             Juan T Dabi
# 93704    93705             Juan T Dabi
# 54497    54498            Manny Garcia
# 57839    57840           Rebecca Duong
# 52792    52793         Nathaniel Intal
# 141804  141805          Eric M Bongato
# 65807    65808               Randi Paz
# 65835    65836  Jesse Laurence Saldana
# 137528  137529         Malika I Crosby
# 141903  141904       Billy Ray C Pablo
# 23391    23392           MARIO YEDIDIA
# 98074    98075           Phimy  Truong
# 138458  138459            Phimy Truong
# 103333  103334         Mario R Yedidia
# 58842    58843           Mario Yedidia
# 18778    18779             MYRON SULAK
#
#                                               JobTitle   BasePay  OvertimePay  \
# 24456                                    ACCOUNT CLERK  49777.81         0.00
# 35637                                    ACCOUNT CLERK    614.00         0.00
# 26437                                    ACCOUNT CLERK  40702.64      1316.73
# 24574                                    ACCOUNT CLERK  49777.86         0.00
# 26235                                    ACCOUNT CLERK  43417.74         0.00
# 24779                                    ACCOUNT CLERK  49777.80         0.00
# 26443                                    ACCOUNT CLERK  40776.98      1183.24
# 27189                                    ACCOUNT CLERK  36149.24       167.08
# 20765                                    ACCOUNT CLERK  60838.20         0.00
# 28014                                    ACCOUNT CLERK  29553.77         0.00
# 25238                                    ACCOUNT CLERK  47405.86         0.00
# 24766                                    ACCOUNT CLERK  49777.86         0.00
# 22972                                    ACCOUNT CLERK  49778.15      3811.68
# 27761                                    ACCOUNT CLERK  31942.84         0.00
# 24767                                    ACCOUNT CLERK  49777.85         0.00
# 24577                                    ACCOUNT CLERK  49777.80         0.00
# 27567                                    ACCOUNT CLERK  33220.71         0.00
# 24578                                    ACCOUNT CLERK  49777.81         0.00
# 24777                                    ACCOUNT CLERK  49777.80         0.00
# 24776                                    ACCOUNT CLERK  49777.81         0.00
# 24416                                    ACCOUNT CLERK  49777.80         0.00
# 24449                                    ACCOUNT CLERK  49777.80         0.00
# 24758                                    ACCOUNT CLERK  49777.84        34.91
# 26289                                    ACCOUNT CLERK  43032.03         0.00
# 26342                                    ACCOUNT CLERK  42709.82         0.00
# 25387                                    ACCOUNT CLERK  47742.68         0.00
# 24793                                    ACCOUNT CLERK  49740.68         0.00
# 24788                                    ACCOUNT CLERK  49768.90         0.00
# 24636                                    ACCOUNT CLERK  49777.80       453.84
# 29433                                    ACCOUNT CLERK  19572.53         0.00
# ...                                                ...       ...          ...
# 139672                           X-Ray Laboratory Aide  24706.72      2266.30
# 90102                            X-Ray Laboratory Aide  61687.50     16979.12
# 127941                           X-Ray Laboratory Aide  65470.37     12770.10
# 66120                            X-Ray Laboratory Aide  23624.32         0.00
# 56386                            X-Ray Laboratory Aide  62167.29      1966.81
# 55802                            X-Ray Laboratory Aide  62256.22      3193.48
# 95045                            X-Ray Laboratory Aide  61670.96      1112.70
# 66095                            X-Ray Laboratory Aide  23243.34         0.00
# 141976                           X-Ray Laboratory Aide  19031.51         0.00
# 126697                           X-Ray Laboratory Aide  58956.65     24457.83
# 130097                           X-Ray Laboratory Aide  65542.79      5140.17
# 109794                           X-Ray Laboratory Aide   1007.00         0.00
# 103259                           X-Ray Laboratory Aide  25376.40         0.00
# 99851                            X-Ray Laboratory Aide  44472.98         0.00
# 136430                           X-Ray Laboratory Aide  50578.02         0.00
# 93704                            X-Ray Laboratory Aide  66122.99         0.00
# 54497                            X-Ray Laboratory Aide  62199.50      1601.67
# 57839                            X-Ray Laboratory Aide  55246.57      3625.58
# 52792                            X-Ray Laboratory Aide  55256.70     20141.45
# 141804                           X-Ray Laboratory Aide  20000.50         0.00
# 65807                            X-Ray Laboratory Aide  25897.31         0.00
# 65835                            X-Ray Laboratory Aide  25627.59         0.00
# 137528                           X-Ray Laboratory Aide  40097.50      5183.46
# 141903                           X-Ray Laboratory Aide  18755.21         0.00
# 23391   YOUTH COMMISSION ADVISOR, BOARD OF SUPERVISORS  52609.91         0.00
# 98074                               Youth Comm Advisor  52433.88         0.00
# 138458                              Youth Comm Advisor  32417.42         0.00
# 103333                              Youth Comm Advisor  13915.80         0.00
# 58842                               Youth Comm Advisor  57544.73         0.00
# 18778                                      ZOO CURATOR  43148.00         0.00
#
#         OtherPay  Benefits  TotalPay  TotalPayBenefits  Year  Notes  \
# 24456    1040.00       NaN  50817.81          50817.81  2011    NaN
# 35637       0.00       NaN    614.00            614.00  2011    NaN
# 26437       0.00       NaN  42019.37          42019.37  2011    NaN
# 24574     624.01       NaN  50401.87          50401.87  2011    NaN
# 26235       0.00       NaN  43417.74          43417.74  2011    NaN
# 24779       0.00       NaN  49777.80          49777.80  2011    NaN
# 26443       0.00       NaN  41960.22          41960.22  2011    NaN
# 27189       0.00       NaN  36316.32          36316.32  2011    NaN
# 20765       0.00       NaN  60838.20          60838.20  2011    NaN
# 28014     427.80       NaN  29981.57          29981.57  2011    NaN
# 25238     920.00       NaN  48325.86          48325.86  2011    NaN
# 24766       0.00       NaN  49777.86          49777.86  2011    NaN
# 22972    1084.76       NaN  54674.59          54674.59  2011    NaN
# 27761     162.75       NaN  32105.59          32105.59  2011    NaN
# 24767       0.00       NaN  49777.85          49777.85  2011    NaN
# 24577     624.03       NaN  50401.83          50401.83  2011    NaN
# 27567     418.24       NaN  33638.95          33638.95  2011    NaN
# 24578     624.00       NaN  50401.81          50401.81  2011    NaN
# 24777       0.00       NaN  49777.80          49777.80  2011    NaN
# 24776       0.00       NaN  49777.81          49777.81  2011    NaN
# 24416    1160.00       NaN  50937.80          50937.80  2011    NaN
# 24449    1064.01       NaN  50841.81          50841.81  2011    NaN
# 24758       0.00       NaN  49812.75          49812.75  2011    NaN
# 26289       0.00       NaN  43032.03          43032.03  2011    NaN
# 26342       0.00       NaN  42709.82          42709.82  2011    NaN
# 25387       0.00       NaN  47742.68          47742.68  2011    NaN
# 24793       0.00       NaN  49740.68          49740.68  2011    NaN
# 24788       0.00       NaN  49768.90          49768.90  2011    NaN
# 24636       0.00       NaN  50231.64          50231.64  2011    NaN
# 29433       0.00       NaN  19572.53          19572.53  2011    NaN
# ...          ...       ...       ...               ...   ...    ...
# 139672    250.00  11253.98  27223.02          38477.00  2014    NaN
# 90102    2456.81  26352.09  81123.43         107475.52  2013    NaN
# 127941    330.00  28140.71  78570.47         106711.18  2014    NaN
# 66120       0.00   1830.70  23624.32          25455.02  2012    NaN
# 56386     250.00  29815.82  64384.10          94199.92  2012    NaN
# 55802    1116.12  30197.86  66565.82          96763.68  2012    NaN
# 95045     359.61  25932.36  63143.27          89075.63  2013    NaN
# 66095     287.66   2112.36  23531.00          25643.36  2012    NaN
# 141976      0.00    190.32  19031.51          19221.83  2014    NaN
# 126697   1705.50  25664.43  85119.98         110784.41  2014    NaN
# 130097    250.00  28154.97  70932.96          99087.93  2014    NaN
# 109794      0.00     10.07   1007.00           1017.07  2013    NaN
# 103259      0.00    253.78  25376.40          25630.18  2013    NaN
# 99851     200.00  18630.21  44672.98          63303.19  2013    NaN
# 136430    730.05  21861.29  51308.07          73169.36  2014    NaN
# 93704     848.00  26904.84  66970.99          93875.83  2013    NaN
# 54497    5865.97  32234.86  69667.14         101902.00  2012    NaN
# 57839    1010.00  29286.23  59882.15          89168.38  2012    NaN
# 52792    2100.97  29673.29  77499.12         107172.41  2012    NaN
# 141804      0.00    200.01  20000.50          20200.51  2014    NaN
# 65807       0.00   2194.76  25897.31          28092.07  2012    NaN
# 65835      78.97   2178.46  25706.56          27885.02  2012    NaN
# 137528    250.00  17350.37  45530.96          62881.33  2014    NaN
# 141903    737.49    194.93  19492.70          19687.63  2014    NaN
# 23391    1022.96       NaN  53632.87          53632.87  2011    NaN
# 98074       0.00  25297.50  52433.88          77731.38  2013    NaN
# 138458   4048.49  15545.28  36465.91          52011.19  2014    NaN
# 103333   5296.91   5744.53  19212.71          24957.24  2013    NaN
# 58842       0.00  28229.66  57544.73          85774.39  2012    NaN
# 18778   23538.56       NaN  66686.56          66686.56  2011    NaN
#
#                Agency  Status
# 24456   San Francisco     NaN
# 35637   San Francisco     NaN
# 26437   San Francisco     NaN
# 24574   San Francisco     NaN
# 26235   San Francisco     NaN
# 24779   San Francisco     NaN
# 26443   San Francisco     NaN
# 27189   San Francisco     NaN
# 20765   San Francisco     NaN
# 28014   San Francisco     NaN
# 25238   San Francisco     NaN
# 24766   San Francisco     NaN
# 22972   San Francisco     NaN
# 27761   San Francisco     NaN
# 24767   San Francisco     NaN
# 24577   San Francisco     NaN
# 27567   San Francisco     NaN
# 24578   San Francisco     NaN
# 24777   San Francisco     NaN
# 24776   San Francisco     NaN
# 24416   San Francisco     NaN
# 24449   San Francisco     NaN
# 24758   San Francisco     NaN
# 26289   San Francisco     NaN
# 26342   San Francisco     NaN
# 25387   San Francisco     NaN
# 24793   San Francisco     NaN
# 24788   San Francisco     NaN
# 24636   San Francisco     NaN
# 29433   San Francisco     NaN
# ...               ...     ...
# 139672  San Francisco     NaN
# 90102   San Francisco     NaN
# 127941  San Francisco     NaN
# 66120   San Francisco     NaN
# 56386   San Francisco     NaN
# 55802   San Francisco     NaN
# 95045   San Francisco     NaN
# 66095   San Francisco     NaN
# 141976  San Francisco     NaN
# 126697  San Francisco     NaN
# 130097  San Francisco     NaN
# 109794  San Francisco     NaN
# 103259  San Francisco     NaN
# 99851   San Francisco     NaN
# 136430  San Francisco     NaN
# 93704   San Francisco     NaN
# 54497   San Francisco     NaN
# 57839   San Francisco     NaN
# 52792   San Francisco     NaN
# 141804  San Francisco     NaN
# 65807   San Francisco     NaN
# 65835   San Francisco     NaN
# 137528  San Francisco     NaN
# 141903  San Francisco     NaN
# 23391   San Francisco     NaN
# 98074   San Francisco     NaN
# 138458  San Francisco     NaN
# 103333  San Francisco     NaN
# 58842   San Francisco     NaN
# 18778   San Francisco     NaN
#
# [148654 rows x 13 columns]

# %%
#How many Job Titles were represented by only one person in 2013? (e.g. Job Titles with only one occurence in 2013?)
sum(data_df[data_df["Year"]==2013]['JobTitle'].value_counts()==1)
# Out:
# 202

# %%
#How many people have the word Chief in their job title?
sum(data_df['JobTitle'].apply(lambda x: 'CHIEF' in x.upper()))
# Out:
# 627

# %%
#Is there a correlation between length of the Job Title string and Salary?

#This is creating a new column with the built in python method 'len'
data_df['JobTitleLength'] = data_df['JobTitle'].apply(len)

data_df[['JobTitleLength','TotalPayBenefits']].corr()
# Out:
#                   JobTitleLength  TotalPayBenefits
# JobTitleLength          1.000000         -0.036878
# TotalPayBenefits       -0.036878          1.000000

# %%
# example of using len
trial_String = "This is a string"
len(trial_String)
# Out:
# 16
